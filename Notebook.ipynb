# %%
import pandas as pd

patients_df = pd.read_json('pandas_json.txt')
patients_df.head()
# Out:
#            name  gt_corners  rb_corners       mean        max       min  \
# 0  Schlafzimmer           4           4   3.956313   8.562939  0.274574
# 1         Küche           4           4  23.019122  52.605437  0.724299
# 2      Bathroom           4           4   1.013833   1.950322  0.301673
# 3  Lounge/Diner           8           8   3.832620  18.236935  0.173307
# 4    Essbereich           4           4   8.017758  15.642853  0.762948
#
#    floor_mean  floor_max  floor_min  ceiling_mean  ceiling_max  ceiling_min
# 0    3.987864   8.562939   0.274574      3.924762     8.501885     0.331494
# 1    1.253103   1.897612   0.724299     44.785141    52.605437    36.880814
# 2    0.659138   1.318714   0.301673      1.368528     1.950322     0.878106
# 3    3.600083  15.041431   0.173307      4.065157    18.236935     0.253457
# 4    7.819446  15.399635   0.762948      8.216069    15.642853     0.909029

# %%
from main import DrawingPlots

dp = DrawingPlots("pandas_json.txt",None,[])
dp.draw_plots()
# Out:
# ['Путь к сохраненному графику:plots/all_plots.pdf']

# %%
from main import DrawingPlots

dp = DrawingPlots("pandas_json.txt","gt_corners",[])
dp.draw_plots()
# Out:
# ['Путь к сохраненному графику:plots/gt_corners.pdf']

# %%
from main import DrawingPlots

dp = DrawingPlots("pandas_json.txt","rb_corners",[])
dp.draw_plots()
# Out:
# ['Путь к сохраненному графику:plots/rb_corners.pdf']

# %%
from main import DrawingPlots

dp = DrawingPlots("pandas_json.txt","mean",[])
dp.draw_plots()
# Out:
# ['Путь к сохраненному графику:plots/mean.pdf']

# %%
from main import DrawingPlots

dp = DrawingPlots("pandas_json.txt","max",[])
dp.draw_plots()
# Out:
# ['Путь к сохраненному графику:plots/max.pdf']

# %%
from main import DrawingPlots

dp = DrawingPlots("pandas_json.txt","min",[])
dp.draw_plots()
# Out:
# ['Путь к сохраненному графику:plots/min.pdf']

# %%
from main import DrawingPlots

dp = DrawingPlots("pandas_json.txt","floor_mean",[])
dp.draw_plots()
# Out:
# ['Путь к сохраненному графику:plots/floor_mean.pdf']

# %%
from main import DrawingPlots

dp = DrawingPlots("pandas_json.txt","floor_max",[])
dp.draw_plots()
# Out:
# ['Путь к сохраненному графику:plots/floor_max.pdf']

# %%
from main import DrawingPlots

dp = DrawingPlots("pandas_json.txt","floor_min",[])
dp.draw_plots()
# Out:
# ['Путь к сохраненному графику:plots/floor_min.pdf']

# %%
from main import DrawingPlots

dp = DrawingPlots("pandas_json.txt","ceiling_mean",[])
dp.draw_plots()
# Out:
# ['Путь к сохраненному графику:plots/ceiling_mean.pdf']

# %%
from main import DrawingPlots

dp = DrawingPlots("pandas_json.txt","ceiling_max",[])
dp.draw_plots()
# Out:
# ['Путь к сохраненному графику:plots/ceiling_max.pdf']

# %%
from main import DrawingPlots

dp = DrawingPlots("pandas_json.txt","ceiling_min",[])
dp.draw_plots()
# Out:
# ['Путь к сохраненному графику:plots/ceiling_min.pdf']
